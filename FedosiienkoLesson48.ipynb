# %% [markdown]
# # Завдання

# %% [markdown]
# Застосуйте різні методи трансформації даних на датасеті Data_to_Transform, що міститься на GitHub в папці лекції. Цей датасет містить чотири колонки, що відповідають:
#
# 1. помірно зміщеним вправо даним (Moderate Positive Skew)
# 2. сильно зміщеним вправо даним (Highly Positive Skew)
# 3. помірно зміщеним вліво даним (Moderate Negative Skew)
# 4. сильно зміщеним вліво даним (Highly Negative Skew)
#
# Оцініть результати трансформацій через квантильно-квантильні графіки.

# %% [markdown]
# # Розв'язок

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm

# %%
df = pd.read_csv('Data_to_Transform.csv')
df
# Out:
#       Moderate Positive Skew  Highly Positive Skew  Moderate Negative Skew  \
# 0                   0.899990              2.895074               11.180748
# 1                   1.113554              2.962385               10.842938
# 2                   1.156830              2.966378               10.817934
# 3                   1.264131              3.000324               10.764570
# 4                   1.323914              3.012109               10.753117
# ...                      ...                   ...                     ...
# 9995               14.749050             16.289513               -2.980821
# 9996               14.854474             16.396252               -3.147526
# 9997               15.262103             17.102991               -3.517256
# 9998               15.269983             17.628467               -4.689833
# 9999               16.204517             18.052331               -6.335679
#
#       Highly Negative Skew
# 0                 9.027485
# 1                 9.009762
# 2                 9.006134
# 3                 9.000125
# 4                 8.981296
# ...                    ...
# 9995             -3.254882
# 9996             -3.772332
# 9997             -4.717950
# 9998             -5.670496
# 9999             -7.036091
#
# [10000 rows x 4 columns]

# %% [markdown]
# ### Серія Moderate Positive Skew

# %%
sns.histplot(df['Moderate Positive Skew'])
fig = plt.figure()

# %%
df_log = np.log(df['Moderate Positive Skew'])
sns.histplot(df_log)
fig = plt.figure()

# %%
df_cbrt = np.cbrt(df['Moderate Positive Skew'])
sns.histplot(df_cbrt)
fig = plt.figure()

# %%
from sklearn.preprocessing import PowerTransformer
data = df['Moderate Positive Skew'].values.reshape(-1, 1)
pt = PowerTransformer(method='box-cox')
df_boxcox = pt.fit_transform(data)
sns.histplot(df_boxcox)
fig = plt.figure()

# %%
fig = sm.qqplot(df['Moderate Positive Skew'], line='45')
plt.show()

# %%
fig = sm.qqplot(df_log, line='45')
plt.show()

# %%
fig = sm.qqplot(df_cbrt, line='45')
plt.show()

# %%
fig = sm.qqplot(df_boxcox, line='45')
plt.show()

# %% [markdown]
# ### Серія Highly Positive Skew

# %%
sns.histplot(df['Highly Positive Skew'])
fig = plt.figure()

# %%
df_log = np.log(df['Highly Positive Skew'])
sns.histplot(df_log)
fig = plt.figure()

# %%
df_cbrt = np.cbrt(df['Highly Positive Skew'])
sns.histplot(df_cbrt)
fig = plt.figure()

# %%
data = df['Highly Positive Skew'].values.reshape(-1, 1)
pt = PowerTransformer(method='box-cox')
df_boxcox = pt.fit_transform(data)
sns.histplot(df_boxcox)
fig = plt.figure()

# %%
fig = sm.qqplot(df['Highly Positive Skew'], line='45')
plt.show()

# %%
fig = sm.qqplot(df_log, line='45')
plt.show()

# %%
fig = sm.qqplot(df_cbrt, line='45')
plt.show()

# %%
fig = sm.qqplot(df_boxcox, line='45')
plt.show()

# %% [markdown]
# ### Серія Moderate Negative Skew

# %%
sns.histplot(df['Moderate Negative Skew'])
fig = plt.figure()

# %%
df_log = np.log(df['Moderate Negative Skew'])
sns.histplot(df_log)
fig = plt.figure()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df_cbrt = np.cbrt(df['Moderate Negative Skew'])
sns.histplot(df_cbrt)
fig = plt.figure()

# %% [markdown]
# ### Серія Highly Negative Skew

# %%
sns.histplot(df['Highly Negative Skew'])
fig = plt.figure()

# %%
df_log = np.log(df['Highly Negative Skew'])
sns.histplot(df_log)
fig = plt.figure()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df_cbrt = np.cbrt(df['Highly Negative Skew'])
sns.histplot(df_cbrt)
fig = plt.figure()

# %%
fig = sm.qqplot(df['Highly Negative Skew'], line='45')
plt.show()

# %%
fig = sm.qqplot(df_log, line='45')
plt.show()

# %%
fig = sm.qqplot(df_cbrt, line='45')
plt.show()

# %% [markdown]
# **Cерії "Moderate Negative Skew" та "Highly Negative Skew" містять негативні значення, до них не було застосовано метод Box-Cox Transformation. Значення інших серій аналізованого датасету найбільш якісно вдалось наблизити до нормального розподілу за допомогою саме методу Box-Cox Transformation.**
